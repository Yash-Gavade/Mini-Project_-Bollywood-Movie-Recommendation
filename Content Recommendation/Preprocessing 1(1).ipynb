# %%
import numpy as np
import pandas as pd
import requests
import bs4 as bs
import urllib.request

# %%
df = pd.read_csv('IMDb.csv',encoding='latin-1')

# %%
df
# Out:
#        userId  Movie_id                                Name    Year Duration  \
# 0           1         1                                         NaN      NaN
# 1           3         3  #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 2           5         5                         #Homecoming -2021.0   90 min
# 3           6         6                             #Yaaram -2019.0  110 min
# 4           8         8                   ...And Once Again -2010.0  105 min
# ...       ...       ...                                 ...     ...      ...
# 15504   25354     25354                 Zulm Ko Jala Doonga -1988.0      NaN
# 15505   25355     25355                               Zulmi -1999.0  129 min
# 15506   25356     25356                           Zulmi Raj -2005.0      NaN
# 15507   25357     25357                       Zulmi Shikari -1988.0      NaN
# 15508   25358     25358                        Zulm-O-Sitam -1998.0  130 min
#
# ...

# %%
list(df.columns)
# Out:
# ['userId',
#  'Movie_id',
#  'Name',
#  'Year',
#  'Duration',
#  'Genre',
#  'Rating',
#  'Votes',
#  'Director',
#  'Actor 1',
#  'Actor 2',
#  'Actor 3']

# %%
df =df.rename(columns={'Name':'Movie_Title'})
df =df.rename(columns={'Year':'Released_Year'})

# %%
new_df = df.dropna()

print(new_df.to_string())
# Out:
#        userId  Movie_id                                                           Movie_Title  Released_Year Duration                            Genre  Rating     Votes                      Director                       Actor 1                          Actor 2                    Actor 3
# 1           3         3                                    #Gadhvi (He thought he was Gandhi)        -2019.0  109 min                            Drama     7.0         8                 Gaurav Bakshi                  Rasika Dugal                   Vivek Ghamande              Arvind Jangid
# 3           6         6                                                               #Yaaram        -2019.0  110 min                  Comedy, Romance     4.4        35                    Ovais Khan                       Prateik                       Ishita Raj            Siddhant Kapoor
# ...

# %%
new_df.isnull().sum()
# Out:
# userId           0
# Movie_id         0
# Movie_Title      0
# Released_Year    0
# Duration         0
# Genre            0
# Rating           0
# Votes            0
# Director         0
# Actor 1          0
# Actor 2          0
# Actor 3          0
# dtype: int64

# %%
df
# Out:
#        userId  Movie_id                         Movie_Title  Released_Year  \
# 0           1         1                                                NaN
# 1           3         3  #Gadhvi (He thought he was Gandhi)        -2019.0
# 2           5         5                         #Homecoming        -2021.0
# 3           6         6                             #Yaaram        -2019.0
# 4           8         8                   ...And Once Again        -2010.0
# ...       ...       ...                                 ...            ...
# 15504   25354     25354                 Zulm Ko Jala Doonga        -1988.0
# 15505   25355     25355                               Zulmi        -1999.0
# 15506   25356     25356                           Zulmi Raj        -2005.0
# 15507   25357     25357                       Zulmi Shikari        -1988.0
# 15508   25358     25358                        Zulm-O-Sitam        -1998.0
#
#       Duration            Genre  Rating Votes            Director  \
# ...

# %%
df.to_csv('Bollywood_Movies.csv')
