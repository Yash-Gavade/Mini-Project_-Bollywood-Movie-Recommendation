# %%
import numpy as np
import pandas as pd

# %%
FIN_df = pd.read_csv('Final_DATA1.csv')

# %%
FIN_df
# Out:
#       Unnamed: 0.1  Unnamed: 0 imdb_title_id                      title  \
# 0                0       439.0     tt0016240                Prem Sanyas
# 1                1       672.0     tt0019374                     Shiraz
# 2                2       787.0     tt0020286             Prapancha Pash
# 3                3      1016.0     tt0021594                   Alam Ara
# 4                4      2308.0     tt0027256               Achhut Kanya
# ...            ...         ...           ...                        ...
# 6368          6368     85844.0     tt9903716                     Jessie
# 6369          6369     85847.0     tt9905412                      Ottam
# 6370          6370     85848.0     tt9905462                  Pengalila
# 6371          6371     85849.0     tt9906644                  Manoharam
# 6372          6372     85852.0     tt9911774  Padmavyuhathile Abhimanyu
#
#                  original_title    year date_published  \
# 0                   Prem Sanyas  1925.0     1926-02-04
# 1                        Shiraz  1928.0     1929-10-21
# 2                Prapancha Pash  1929.0           2008
# 3                      Alam Ara  1931.0     1931-03-14
# 4                  Achhut Kanya  1936.0           1936
# ...                         ...     ...            ...
# 6368                     Jessie  2019.0     2019-03-15
# 6369                      Ottam  2019.0     2019-03-08
# 6370                  Pengalila  2019.0     2019-03-08
# 6371                  Manoharam  2019.0     2019-09-27
# 6372  Padmavyuhathile Abhimanyu  2019.0     2019-03-08
#
#                           genre  duration             country  ...  \
# 0                         Drama      97.0      India, Germany  ...
# 1       Drama, History, Romance      97.0  India, UK, Germany  ...
# 2     Adventure, Drama, Romance      74.0  UK, India, Germany  ...
# 3                Drama, Fantasy     124.0               India  ...
# 4       Drama, Musical, Romance     142.0               India  ...
# ...                         ...       ...                 ...  ...
# 6368           Horror, Thriller     106.0               India  ...
# 6369                      Drama     120.0               India  ...
# 6370                      Drama     111.0               India  ...
# 6371              Comedy, Drama     122.0               India  ...
# 6372                      Drama     130.0               India  ...
#
#      worldwide_gross_income metascore reviews_from_users reviews_from_critics  \
# 0                       NaN       NaN                3.0                  1.0
# 1                   16467.0       NaN                4.0                  9.0
# 2                    2306.0       NaN                8.0                 14.0
# 3                       NaN       NaN                NaN                  1.0
# 4                       NaN       NaN                2.0                  1.0
# ...                     ...       ...                ...                  ...
# 6368                    NaN       NaN               27.0                  NaN
# 6369                 4791.0       NaN                1.0                  NaN
# 6370                    NaN       NaN                NaN                  NaN
# 6371                    NaN       NaN                9.0                  1.0
# 6372                    NaN       NaN                NaN                  NaN
#
#      Director Actor  genres  movie_title  Actor_name  comb
# 0         NaN   NaN     NaN          NaN         NaN   NaN
# 1         NaN   NaN     NaN          NaN         NaN   NaN
# 2         NaN   NaN     NaN          NaN         NaN   NaN
# 3         NaN   NaN     NaN          NaN         NaN   NaN
# 4         NaN   NaN     NaN          NaN         NaN   NaN
# ...       ...   ...     ...          ...         ...   ...
# 6368      NaN   NaN     NaN          NaN         NaN   NaN
# 6369      NaN   NaN     NaN          NaN         NaN   NaN
# 6370      NaN   NaN     NaN          NaN         NaN   NaN
# 6371      NaN   NaN     NaN          NaN         NaN   NaN
# 6372      NaN   NaN     NaN          NaN         NaN   NaN
#
# [6373 rows x 30 columns]

# %%
imdb_movies = FIN_df

# %%
imdb_movies
# Out:
#       Unnamed: 0.1  Unnamed: 0 imdb_title_id                      title  \
# 0                0       439.0     tt0016240                Prem Sanyas
# 1                1       672.0     tt0019374                     Shiraz
# 2                2       787.0     tt0020286             Prapancha Pash
# 3                3      1016.0     tt0021594                   Alam Ara
# 4                4      2308.0     tt0027256               Achhut Kanya
# ...            ...         ...           ...                        ...
# 6368          6368     85844.0     tt9903716                     Jessie
# 6369          6369     85847.0     tt9905412                      Ottam
# 6370          6370     85848.0     tt9905462                  Pengalila
# 6371          6371     85849.0     tt9906644                  Manoharam
# 6372          6372     85852.0     tt9911774  Padmavyuhathile Abhimanyu
#
#                  original_title    year date_published  \
# 0                   Prem Sanyas  1925.0     1926-02-04
# 1                        Shiraz  1928.0     1929-10-21
# 2                Prapancha Pash  1929.0           2008
# 3                      Alam Ara  1931.0     1931-03-14
# 4                  Achhut Kanya  1936.0           1936
# ...                         ...     ...            ...
# 6368                     Jessie  2019.0     2019-03-15
# 6369                      Ottam  2019.0     2019-03-08
# 6370                  Pengalila  2019.0     2019-03-08
# 6371                  Manoharam  2019.0     2019-09-27
# 6372  Padmavyuhathile Abhimanyu  2019.0     2019-03-08
#
#                           genre  duration             country  ...  \
# 0                         Drama      97.0      India, Germany  ...
# 1       Drama, History, Romance      97.0  India, UK, Germany  ...
# 2     Adventure, Drama, Romance      74.0  UK, India, Germany  ...
# 3                Drama, Fantasy     124.0               India  ...
# 4       Drama, Musical, Romance     142.0               India  ...
# ...                         ...       ...                 ...  ...
# 6368           Horror, Thriller     106.0               India  ...
# 6369                      Drama     120.0               India  ...
# 6370                      Drama     111.0               India  ...
# 6371              Comedy, Drama     122.0               India  ...
# 6372                      Drama     130.0               India  ...
#
#      worldwide_gross_income metascore reviews_from_users reviews_from_critics  \
# 0                       NaN       NaN                3.0                  1.0
# 1                   16467.0       NaN                4.0                  9.0
# 2                    2306.0       NaN                8.0                 14.0
# 3                       NaN       NaN                NaN                  1.0
# 4                       NaN       NaN                2.0                  1.0
# ...                     ...       ...                ...                  ...
# 6368                    NaN       NaN               27.0                  NaN
# 6369                 4791.0       NaN                1.0                  NaN
# 6370                    NaN       NaN                NaN                  NaN
# 6371                    NaN       NaN                9.0                  1.0
# 6372                    NaN       NaN                NaN                  NaN
#
#      Director Actor  genres  movie_title  Actor_name  comb
# 0         NaN   NaN     NaN          NaN         NaN   NaN
# 1         NaN   NaN     NaN          NaN         NaN   NaN
# 2         NaN   NaN     NaN          NaN         NaN   NaN
# 3         NaN   NaN     NaN          NaN         NaN   NaN
# 4         NaN   NaN     NaN          NaN         NaN   NaN
# ...       ...   ...     ...          ...         ...   ...
# 6368      NaN   NaN     NaN          NaN         NaN   NaN
# 6369      NaN   NaN     NaN          NaN         NaN   NaN
# 6370      NaN   NaN     NaN          NaN         NaN   NaN
# 6371      NaN   NaN     NaN          NaN         NaN   NaN
# 6372      NaN   NaN     NaN          NaN         NaN   NaN
#
# [6373 rows x 30 columns]

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
a = plt.cm.cool

plt.figure(figsize=(15,10))
count = imdb_movies['production_company'].value_counts()[:10]
sns.barplot(count.values, count.index, palette=[a(0.1),a(0.2),a(0.3),a(0.4),a(0.5),a(0.6),a(0.7),a(0.8),a(0.9),a(0.99)])
for i, v in enumerate(count.values):
    plt.text(0.8,i,v,color='k',fontsize=14)
plt.xlabel('Count')
plt.ylabel('Production Company name')
plt.title("Distribution of Studio names")
# Out:
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Studio names')

# %%
a = plt.cm.autumn

plt.figure(figsize=(15,10))
count = imdb_movies['genre'].value_counts()[:10]
sns.barplot(count.values, count.index, palette=[a(0.1),a(0.2),a(0.3),a(0.4),a(0.5),a(0.6),a(0.7),a(0.8),a(0.9),a(0.99)])
for i, v in enumerate(count.values):
    plt.text(0.8,i,v,color='k',fontsize=14)
plt.xlabel('Count')
plt.ylabel('Genre')
plt.title("Distribution of Genres")
# Out:
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Genres')

# %%
num_data = ['duration', 'avg_vote', 'votes', 'budget', 'usa_gross_income', 'worldwide_gross_income', 
            'metascore', 'reviews_from_users', 'reviews_from_critics']
imdb_movies[num_data].describe()
# Out:
#           duration     avg_vote          votes        budget  \
# count  6373.000000  6373.000000    6373.000000  1.158000e+03
# mean    138.243214     6.216131    3449.462420  1.322012e+08
# std      23.074516     1.423553   18859.366095  3.200706e+08
# min      45.000000     1.000000     100.000000  0.000000e+00
# 25%     123.000000     5.300000     213.000000  9.000000e+06
# 50%     140.000000     6.500000     503.000000  4.000000e+07
# 75%     153.000000     7.200000    1582.000000  1.395000e+08
# max     321.000000     9.900000  786365.000000  5.420000e+09
#
#        usa_gross_income  worldwide_gross_income   metascore  \
# count      6.180000e+02            1.993000e+03  144.000000
# mean       5.200459e+06            1.546427e+07   54.534722
# std        2.448189e+07            7.537878e+07   16.052324
# min        1.416000e+03            4.200000e+01   17.000000
# 25%        1.341840e+05            4.220400e+04   42.750000
# 50%        4.845540e+05            2.432460e+05   55.000000
# 75%        1.431122e+06            1.574703e+06   66.000000
# max        4.045402e+08            1.300000e+09   89.000000
#
#        reviews_from_users  reviews_from_critics
# count         5676.000000           4272.000000
# mean            31.713707             10.147004
# std            168.217414             32.058560
# min              1.000000              1.000000
# 25%              3.000000              1.000000
# 50%              6.000000              3.000000
# 75%             18.000000              9.000000
# max           7639.000000            582.000000

# %%
fig, ax = plt.subplots(9, 2, figsize = (14, 24))
fig.tight_layout(pad = 5)

for i, n in enumerate(num_data):
    sns.distplot(ax = ax[i,0], a = imdb_movies[n].dropna(), label = 'skewness : %.2f'%(imdb_movies[n].skew()))
    ax[i,0].set_title(n, fontsize = 18)
    ax[i,0].legend(loc = 'best')
    
    sns.boxplot(ax = ax[i, 1], x = imdb_movies[n].dropna())
    ax[i, 1].set_title(n, fontsize = 18)
plt.show()
# Out:
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\SOFTWARES\All Softwares\PYTHON\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
imdb_movies['year'].replace('TV Movie 2019', 2019, inplace = True)
imdb_movies['year'] = imdb_movies['year'].astype(int)

# %%
# Grouping the data based on Decades
movies_by_decades = imdb_movies[['imdb_title_id', 'original_title', 'year','avg_vote', 'votes']]
decades = movies_by_decades['year']//10*10
Decades = decades.astype(str)+' - '+ (decades+9).astype(str)
decades_column = pd.DataFrame(decades)

# %%
movies_by_decades.insert(3, 'Decades', decades_column)
movies_by_decades.head()
# Out:
#   imdb_title_id  original_title  year  Decades  avg_vote  votes
# 0     tt0016240     Prem Sanyas  1925     1920       6.8  134.0
# 1     tt0019374          Shiraz  1928     1920       7.0  229.0
# 2     tt0020286  Prapancha Pash  1929     1920       6.5  710.0
# 3     tt0021594        Alam Ara  1931     1930       6.3  106.0
# 4     tt0027256    Achhut Kanya  1936     1930       6.5  104.0

# %%
max_width = 15
fig, ax = plt.subplots(figsize = (16,4))
decades = movies_by_decades.groupby('Decades')['imdb_title_id'].count().index
count = movies_by_decades.groupby('Decades')['imdb_title_id'].count()
sns.barplot(ax = ax, x = decades, y = count)
ax.set_title('Movie Counts Based on Decade', fontsize = 18)
ax.set_xlabel('Decade')
for index,count in enumerate(count.astype(int)):
       ax.text(x=index-0.15 , y =count+1 , s=f"{count}" , fontdict=dict(fontsize=10))
ax.set_ylabel('No. of Movies')
plt.show()

# %%
imdb_movies['date_published'].replace('TV Movie 2019', 2019, inplace = True)
movies_published = imdb_movies[['imdb_title_id', 'original_title', 'genre', 'date_published','votes']]
movies_published['month_published'] = [month[5:7] for month in movies_published['date_published'].astype(str)]

#print(movies_published['month_published'].unique()) # There are blank values on month_published column
movies_published['month_published'][movies_published['month_published']==''] = np.nan # replace blank values with nan
movies_published.head()
# Out:
# C:\Users\yashg\AppData\Local\Temp\ipykernel_24260\1752796610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_published['month_published'] = [month[5:7] for month in movies_published['date_published'].astype(str)]
# C:\Users\yashg\AppData\Local\Temp\ipykernel_24260\1752796610.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_published['month_published'][movies_published['month_published']==''] = np.nan # replace blank values with nan
#   imdb_title_id  original_title                      genre date_published  \
# 0     tt0016240     Prem Sanyas                      Drama     1926-02-04
# 1     tt0019374          Shiraz    Drama, History, Romance     1929-10-21
# 2     tt0020286  Prapancha Pash  Adventure, Drama, Romance           2008
# 3     tt0021594        Alam Ara             Drama, Fantasy     1931-03-14
# 4     tt0027256    Achhut Kanya    Drama, Musical, Romance           1936
#
#    votes month_published
# 0  134.0              02
# 1  229.0              10
# 2  710.0             NaN
# 3  106.0              03
# 4  104.0             NaN

# %%
max_width = 15
fig, ax = plt.subplots(figsize = (16,4))
months_published = movies_published.groupby('month_published')['imdb_title_id'].count().index
count_movies = movies_published.groupby('month_published')['imdb_title_id'].count()
sns.barplot(ax = ax, x = months_published, y = count_movies)
ax.set_title('Movie Counts Based on Month', fontsize = 18)
ax.set_xlabel('Month')
ax.set_ylabel('No. of Movies')
for index,count_movies in enumerate(count_movies):
       ax.text(x=index-0.15 , y =count_movies+0 , s=f"{count_movies}" , fontdict=dict(fontsize=10))
ax.set_xticklabels(['January', 'February', 'March', 'April', 'May', 'June'
                    , 'July', 'August', 'September', 'October', 'November', 'December'])

plt.show()
